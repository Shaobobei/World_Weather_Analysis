# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps


# Import API key
from configuration import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_Database.csv")
city_data_df.head()
# Out:
#    City ID         City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0      Lujiang      CN  31.2581  117.2817     86.85        71
# 1        1     Oksfjord      NO  70.2396   22.3479     57.38        79
# 2        2   Launceston      AU -41.4500  147.1667     54.61        73
# 3        3  Yellowknife      CA  62.4560 -114.3525     68.52        40
# 4        4     Hamilton      US  39.1834  -84.5333     75.31        82
#
#    Cloudiness  Wind Speed Current Description
# 0           0        1.50           clear sky
# 1          60        2.19       broken clouds
# 2          40       13.80    scattered clouds
# 3          40        9.22    scattered clouds
# 4           0        6.91           clear sky

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is your desired minimum temperature for your trip? "))
max_temp = float(input("What is your desired maximum temperature for your trip? "))
# Out:
# What is your desired minimum temperature for your trip? 75
# What is your desired maximum temperature for your trip? 95

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) &
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City ID        City Country      Lat       Lng  Max Temp  Humidity  \
# 0         0     Lujiang      CN  31.2581  117.2817     86.85        71
# 4         4    Hamilton      US  39.1834  -84.5333     75.31        82
# 7         7       Yumen      CN  40.2833   97.2000     76.30        32
# 10       10        Gizo      SB  -8.1030  156.8419     84.52        68
# 12       12   Hithadhoo      MV  -0.6000   73.0833     80.73        74
# 13       13      Avarua      CK -21.2078 -159.7750     77.05        73
# 17       17  Porto Novo      BJ   6.4965    2.6036     75.02        81
# 22       22      Atuona      PF  -9.8000 -139.0333     77.05        73
# 23       23    Montreal      CA  45.5088  -73.5878     75.92        64
# 24       24     Kahului      US  20.8947 -156.4700     87.82        56
#
#     Cloudiness  Wind Speed Current Description
# 0            0        1.50           clear sky
# 4            0        6.91           clear sky
# 7           31       14.03    scattered clouds
# 10           4        3.67           clear sky
# 12         100       16.35     overcast clouds
# 13          20       14.97          few clouds
# 17         100       12.46     overcast clouds
# 22          14       12.68          few clouds
# 23          75       10.36       broken clouds
# 24          20       19.57          few clouds

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.isnull().sum()
# Out:
# City ID                0
# City                   0
# Country                0
# Lat                    0
# Lng                    0
# Max Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = preferred_cities_df.dropna()
clean_df
# Out:
#      City ID       City Country      Lat       Lng  Max Temp  Humidity  \
# 0          0    Lujiang      CN  31.2581  117.2817     86.85        71
# 4          4   Hamilton      US  39.1834  -84.5333     75.31        82
# 7          7      Yumen      CN  40.2833   97.2000     76.30        32
# 10        10       Gizo      SB  -8.1030  156.8419     84.52        68
# 12        12  Hithadhoo      MV  -0.6000   73.0833     80.73        74
# ..       ...        ...     ...      ...       ...       ...       ...
# 669      669      Rawah      IQ  34.4816   41.9093     90.25        21
# 671      671     Lethem      GY   3.3803  -59.7968     75.83        89
# 672      672    Suamico      US  44.6319  -88.0393     77.76        63
# 675      675      Buala      SB  -8.1450  159.5921     85.06        70
# 679      679      Qeshm      IR  26.9581   56.2719     88.12        83
#
#      Cloudiness  Wind Speed Current Description
# 0             0        1.50           clear sky
# 4             0        6.91           clear sky
# 7            31       14.03    scattered clouds
# 10            4        3.67           clear sky
# 12          100       16.35     overcast clouds
# ..          ...         ...                 ...
# 669           0        8.14           clear sky
# 671         100        5.46     overcast clouds
# 672           0        8.05           clear sky
# 675          21       12.15          light rain
# 679          84        6.06       broken clouds
#
# [270 rows x 10 columns]

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#           City Country  Max Temp Current Description      Lat       Lng  \
# 0      Lujiang      CN     86.85           clear sky  31.2581  117.2817
# 4     Hamilton      US     75.31           clear sky  39.1834  -84.5333
# 7        Yumen      CN     76.30    scattered clouds  40.2833   97.2000
# 10        Gizo      SB     84.52           clear sky  -8.1030  156.8419
# 12   Hithadhoo      MV     80.73     overcast clouds  -0.6000   73.0833
# 13      Avarua      CK     77.05          few clouds -21.2078 -159.7750
# 17  Porto Novo      BJ     75.02     overcast clouds   6.4965    2.6036
# 22      Atuona      PF     77.05          few clouds  -9.8000 -139.0333
# 23    Montreal      CA     75.92       broken clouds  45.5088  -73.5878
# 24     Kahului      US     87.82          few clouds  20.8947 -156.4700
#
#    Hotel Name
# 0
# 4
# 7
# 10
# 12
# 13
# 17
# 22
# 23
# 24

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():

    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]

    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.dropna()
print(clean_hotel_df.count())
clean_hotel_df.head()
# Out:
# City                   270
# Country                270
# Max Temp               270
# Current Description    270
# Lat                    270
# Lng                    270
# Hotel Name             270
# dtype: int64
#          City Country  Max Temp Current Description      Lat       Lng  \
# 0     Lujiang      CN     86.85           clear sky  31.2581  117.2817
# 4    Hamilton      US     75.31           clear sky  39.1834  -84.5333
# 7       Yumen      CN     76.30    scattered clouds  40.2833   97.2000
# 10       Gizo      SB     84.52           clear sky  -8.1030  156.8419
# 12  Hithadhoo      MV     80.73     overcast clouds  -0.6000   73.0833
#
#                                            Hotel Name
# 0   GreenTree Inn Hefei Lujiang County Jinjie 1 Ex...
# 4                           Six Acres Bed & Breakfast
# 7
# 10                                 Imagination Island
# 12                                  Scoop Guest House

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok

# %%
# !pip install gmaps
# Out:
# Requirement already satisfied: gmaps in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (0.9.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (7.6.5)
# Requirement already satisfied: geojson>=2.0.0 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (5.1.1)
# Requirement already satisfied: six in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (1.16.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (7.31.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (3.0.20)
# Requirement already satisfied: setuptools>=18.5 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (61.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.18.1)
# Requirement already satisfied: pygments in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (2.11.2)
# Requirement already satisfied: colorama in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.4.4)
# Requirement already satisfied: matplotlib-inline in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: pickleshare in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: decorator in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (5.1.1)
# Requirement already satisfied: backcall in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.3.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (6.9.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.5.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.12)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1)
# Requirement already satisfied: nest-asyncio in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->gmaps) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (4.9.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (22.3.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (302)
# Requirement already satisfied: fastjsonschema in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (2.15.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.4.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (5.2.0)
# Requirement already satisfied: importlib-metadata in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.11.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.18.0)
# Requirement already satisfied: typing-extensions in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (21.4.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.7.0)
# Requirement already satisfied: wcwidth in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.4.8)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.13.1)
# Requirement already satisfied: nbconvert in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.4.4)
# Requirement already satisfied: argon2-cffi in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.8.0)
# Requirement already satisfied: prometheus-client in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.13.1)
# Requirement already satisfied: jinja2 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.3)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.21)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.0.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.13)
# Requirement already satisfied: beautifulsoup4 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: bleach in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: testpath in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: packaging in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\zoeyx\anaconda3\envs\pythondata\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.0.4)

# %%
# !jupyter nbextension enable --py --sys-prefix gmaps
# Out:
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: ok

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
<dt>Description</dt><dd>{Current Description}</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
